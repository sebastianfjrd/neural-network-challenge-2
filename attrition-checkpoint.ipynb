# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split


#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
print("Columns in DataFrame:", attrition_df.columns)
# Out:
# Columns in DataFrame: Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
print("Columns in y_df:", y_df.columns)
# Out:
# Columns in y_df: Index(['Attrition', 'Department'], dtype='object')

# %%
# Create a list of at least 10 column names to use as X data
mycolumns = ['Education', 'DistanceFromHome', 'HourlyRate', 'JobSatisfaction', 'PercentSalaryHike',
             'TotalWorkingYears', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 
             'YearsSinceLastPromotion', 'RelationshipSatisfaction']
# Example list of columns (excluding 'Attrition' and 'Department')


# Create X_df using your selected columns
X_df = attrition_df[mycolumns]


# Show the data types for X_df
X_df.dtypes
# Out:
# Education                   int64
# DistanceFromHome            int64
# HourlyRate                  int64
# JobSatisfaction             int64
# PercentSalaryHike           int64
# TotalWorkingYears           int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# RelationshipSatisfaction    int64
# dtype: object

# %%
# Reshape y values for attrition and department
y_attrition = attrition_df['Attrition'].values.reshape(-1, 1)
y_department = attrition_df['Department'].values.reshape(-1, 1)

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_attrition_train, y_attrition_test, y_department_train, y_department_test = train_test_split(
    X_df, y_attrition, y_department, test_size=0.2, random_state=42)

# %%
# Create a StandardScaler
scaler = StandardScaler()


# Fit the StandardScaler to the training data

scaler.fit(X_train)


# Scale the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create a OneHotEncoder for the Department column
D_encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
D_encoder.fit(y_department_train)
# Out:
# OneHotEncoder(sparse_output=False)

# %%
# Create two new variables by applying the encoder to the training and testing data
y_D_train_encoded = D_encoder.transform(y_department_train)
y_D_test_encoded = D_encoder.transform(y_department_test)

# %%
# Create a LabelEncoder for the Attrition column
encoder = LabelEncoder()
# Fit the encoder to the training data and transform the data
y_attr_train_encoded = encoder.fit_transform(y_attrition_train)
y_attr_test_encoded = encoder.transform(y_attrition_test)
# Out:
# C:\Users\sebas\anaconda3\envs\ai_dev\lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sebas\anaconda3\envs\ai_dev\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data

input_shape = X_train_scaled.shape[1]

# Create the input layer
input_layer = layers.Input(shape=(input_shape,), name='input_features')

# Create at least two shared layers
shared1 = layers.Dense(24, activation='relu')(input_layer)
shared2 = layers.Dense(12, activation='relu')(shared1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
department_hidden = layers.Dense(12, activation='relu', name='department_hidden')(shared2)

# Create the output layer
department_output = layers.Dense(3, activation='softmax', name='department_output')(department_hidden)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer

attrition_hidden = layers.Dense(12, activation='relu', name='attrition_hidden')(shared2)
# Create the output layer
attrition_output = layers.Dense(1, activation='sigmoid', name='attrition_output')(attrition_hidden)

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[department_output, attrition_output])


# Compile the model
model.compile(optimizer='adam',
              loss={'department_output': 'categorical_crossentropy', 'attrition_output': 'binary_crossentropy'},
              metrics={'department_output': 'accuracy', 'attrition_output': 'accuracy'})

# Summarize the model
model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_features (InputLayer)   │ (None, 11)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_45 (Dense)              │ (None, 24)                │             288 │ input_features[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_46 (Dense)              │ (None, 12)                │             300 │ dense_45[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ department_hidden (Dense)     │ (None, 12)                │             156 │ dense_46[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ attrition_hidden (Dense)      │ (None, 12)                │             156 │ dense_46[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ department_output (Dense)     │ (None, 3)                 │              39 │ department_hidden[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ attrition_output (Dense)      │ (None, 1)                 │              13 │ attrition_hidden[0][0]     │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 952 (3.72 KB)
#  Trainable params: 952 (3.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.fit(X_train_scaled, 
          {'department_output': y_D_train_encoded, 'attrition_output': y_attr_train_encoded}, 
          epochs=50, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - attrition_output_accuracy: 0.5889 - department_output_accuracy: 0.3683 - loss: 1.7626 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.4508
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8510 - department_output_accuracy: 0.6762 - loss: 1.2955 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.3354
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8379 - department_output_accuracy: 0.6517 - loss: 1.1985 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.3114
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8291 - department_output_accuracy: 0.6502 - loss: 1.2012 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.3003
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8315 - department_output_accuracy: 0.6479 - loss: 1.1882 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.2916
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8286 - department_output_accuracy: 0.6528 - loss: 1.1746 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.2846
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8400 - department_output_accuracy: 0.6742 - loss: 1.1411 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.2746
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8490 - department_output_accuracy: 0.6862 - loss: 1.1118 - val_attrition_output_accuracy: 0.7924 - val_department_output_accuracy: 0.6314 - val_loss: 1.2718
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8455 - department_output_accuracy: 0.6498 - loss: 1.1443 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.2802
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8612 - department_output_accuracy: 0.6536 - loss: 1.0938 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6314 - val_loss: 1.2693
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8436 - department_output_accuracy: 0.6734 - loss: 1.1219 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.2747
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8606 - department_output_accuracy: 0.6547 - loss: 1.1019 - val_attrition_output_accuracy: 0.8093 - val_department_output_accuracy: 0.6314 - val_loss: 1.2683
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8334 - department_output_accuracy: 0.6541 - loss: 1.1244 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6314 - val_loss: 1.2829
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8603 - department_output_accuracy: 0.6638 - loss: 1.0746 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6314 - val_loss: 1.2749
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8412 - department_output_accuracy: 0.6508 - loss: 1.1041 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6314 - val_loss: 1.2854
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8415 - department_output_accuracy: 0.6450 - loss: 1.1205 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6314 - val_loss: 1.2859
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8684 - department_output_accuracy: 0.6721 - loss: 1.0593 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.2840
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8421 - department_output_accuracy: 0.6553 - loss: 1.1087 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.3054
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8453 - department_output_accuracy: 0.6682 - loss: 1.0634 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6356 - val_loss: 1.3079
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8407 - department_output_accuracy: 0.6639 - loss: 1.0438 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.3104
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8568 - department_output_accuracy: 0.6615 - loss: 1.0748 - val_attrition_output_accuracy: 0.8093 - val_department_output_accuracy: 0.6356 - val_loss: 1.3143
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8414 - department_output_accuracy: 0.6363 - loss: 1.1027 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6356 - val_loss: 1.3267
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8642 - department_output_accuracy: 0.6805 - loss: 1.0230 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.3271
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8733 - department_output_accuracy: 0.6645 - loss: 1.0047 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.3199
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8562 - department_output_accuracy: 0.6370 - loss: 1.0575 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6271 - val_loss: 1.3314
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8488 - department_output_accuracy: 0.6741 - loss: 1.0379 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6271 - val_loss: 1.3334
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8758 - department_output_accuracy: 0.6694 - loss: 0.9803 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6356 - val_loss: 1.3352
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8676 - department_output_accuracy: 0.6534 - loss: 1.0116 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6271 - val_loss: 1.3450
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8808 - department_output_accuracy: 0.6732 - loss: 0.9736 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6441 - val_loss: 1.3492
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8618 - department_output_accuracy: 0.6651 - loss: 1.0106 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6356 - val_loss: 1.3559
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8740 - department_output_accuracy: 0.6348 - loss: 1.0289 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6314 - val_loss: 1.3591
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8831 - department_output_accuracy: 0.6656 - loss: 0.9910 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6398 - val_loss: 1.3523
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8700 - department_output_accuracy: 0.6603 - loss: 1.0176 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.3683
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8787 - department_output_accuracy: 0.6638 - loss: 1.0041 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6398 - val_loss: 1.3756
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8669 - department_output_accuracy: 0.6676 - loss: 0.9957 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6356 - val_loss: 1.3776
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8851 - department_output_accuracy: 0.6933 - loss: 0.9403 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6314 - val_loss: 1.3793
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8883 - department_output_accuracy: 0.6939 - loss: 0.9478 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6356 - val_loss: 1.3744
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8991 - department_output_accuracy: 0.6905 - loss: 0.9457 - val_attrition_output_accuracy: 0.7924 - val_department_output_accuracy: 0.6271 - val_loss: 1.3717
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8656 - department_output_accuracy: 0.6643 - loss: 0.9935 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.3939
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8794 - department_output_accuracy: 0.6497 - loss: 0.9909 - val_attrition_output_accuracy: 0.7966 - val_department_output_accuracy: 0.6441 - val_loss: 1.4046
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8805 - department_output_accuracy: 0.7086 - loss: 0.9644 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6229 - val_loss: 1.3792
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8864 - department_output_accuracy: 0.6909 - loss: 0.9421 - val_attrition_output_accuracy: 0.8136 - val_department_output_accuracy: 0.6314 - val_loss: 1.3880
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8876 - department_output_accuracy: 0.6521 - loss: 0.9997 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6356 - val_loss: 1.3942
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8891 - department_output_accuracy: 0.6758 - loss: 0.9489 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6441 - val_loss: 1.4009
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.9053 - department_output_accuracy: 0.6778 - loss: 0.9210 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6398 - val_loss: 1.4019
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8699 - department_output_accuracy: 0.6995 - loss: 0.9211 - val_attrition_output_accuracy: 0.8093 - val_department_output_accuracy: 0.6398 - val_loss: 1.4064
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8682 - department_output_accuracy: 0.6878 - loss: 0.9591 - val_attrition_output_accuracy: 0.8008 - val_department_output_accuracy: 0.6229 - val_loss: 1.4337
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8725 - department_output_accuracy: 0.6904 - loss: 0.9875 - val_attrition_output_accuracy: 0.8093 - val_department_output_accuracy: 0.6441 - val_loss: 1.4149
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8689 - department_output_accuracy: 0.6883 - loss: 0.9252 - val_attrition_output_accuracy: 0.8051 - val_department_output_accuracy: 0.6441 - val_loss: 1.4088
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8699 - department_output_accuracy: 0.6741 - loss: 0.9479 - val_attrition_output_accuracy: 0.7924 - val_department_output_accuracy: 0.6356 - val_loss: 1.4475

# %%
# Evaluate the model with the testing data
# Evaluate the model with the testing data
results = model.evaluate(X_test_scaled, 
                         {'department_output': y_D_test_encoded, 'attrition_output': y_attr_test_encoded})
# Print the accuracy for both department and attrition
pred_categories = ['department', 'attrition']
for i, cat in enumerate(pred_categories):
    print(f"{cat} accuracy: {results[i+1]}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8087 - department_output_accuracy: 0.5551 - loss: 1.4326
# department accuracy: 0.8231292366981506
# attrition accuracy: 0.5850340127944946

# %%
# Print the results to see what is being returned
print("Evaluation Results:", results)
# Out:
# Evaluation Results: [1.409824252128601, 0.8231292366981506, 0.5850340127944946]

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
# 2. What activation functions did you choose for your output layers, and why?
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. My thoughts are accuracy isn't always the best metric, especially if the data is imbalanced. For example, if most employees stay and few leave, predicting everyone stays could give high accuracy but isn't useful. Metrics like precision, recall, F1-score, and ROC-AUC are better because they give a fuller picture of how well the model is performing.
# 2. I used Softmax for Department Prediction: This is used because it’s a multi-class problem. Softmax gives a probability for each department, making it clear which department is the best fit for each employee.
# And I used; Sigmoid for Attrition Prediction: This is used for the binary problem of predicting whether an employee will stay or leave. Sigmoid gives a probability between 0 and 1, which is perfect for this yes/no type of question.
#
# 3. There are several methods to enhance a model performance such as:
# a. Tune Hyperparameters: Adjust things like the number of layers, neurons, learning rate, batch size, and epochs to find the best settings.
# b. Use Cross-Validation: Split the data into multiple parts and train the model on each part to get a more reliable performance estimate.
# c. Feature Engineering: Create new features or select the most relevant ones to improve the model's input data.
# d. Handle Class Imbalance: Use techniques like SMOTE or class weighting to make sure the model learns well from both common and rare classes.
# e. Try Different Architectures: Experiment with more layers, different types of layers, or dropout layers to prevent overfitting.
# f. Ensemble Methods: Combine predictions from multiple models to reduce errors and improve overall performance.
# These improvements can make the model more accurate and reliable in predicting employee attrition and the best department for each employee.
#
# But having more data is always key.
